# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
from ipywidgets import interact,widgets
newd=pd.read_csv("covid19.csv")
newd.head(10)
# Out:
#         date  total_cas_confirmes  total_deces_hopital  patients_reanimation  \
# 0  4/12/2020                95403                 9253                  6845
# 1  4/13/2020                98076                 9588                  6821
# 2  4/14/2020               103573                10129                  6730
# 3  4/15/2020               106206                10643                  6457
# 4  4/16/2020               108847                11060                  6248
# 5  4/17/2020               109252                11478                  6027
# 6  4/18/2020               111821                11842                  5833
# 7  4/19/2020               112606                12069                  5744
# 8  4/20/2020               114657                12513                  5683
# 9  4/22/2020               119151                13236                  5218
#
#    patients_hospitalises  total_patients_gueris  \
# 0                  31826                  27186
# ...

# %%
newd.tail()
# Out:
#           date  total_cas_confirmes  total_deces_hopital  \
# 306  2/15/2021              3469539                58227
# 307  2/16/2021              3489129                58578
# 308  2/17/2021              3514147                58888
# 309  2/18/2021              3536648                59159
# 310  2/19/2021              3560764                59484
#
#      patients_reanimation  patients_hospitalises  total_patients_gueris  \
# 306                  3381                  26522                 242528
# 307                  3348                  26239                 244238
# 308                  3350                  25974                 245737
# 309                  3394                  25762                 247127
# 310                  3390                  25551                 248488
#
#      nouveaux_patients_hospitalises  nouveaux_patients_reanimation  \
# 306                            1426                            306
# ...

# %%
newd.shape
# Out:
# (311, 16)

# %%
newd.describe()
# Out:
#        total_cas_confirmes  total_deces_hopital  patients_reanimation  \
# count         3.110000e+02           311.000000            311.000000
# mean          1.125829e+06         27751.881029           2184.327974
# std           1.157963e+06         13004.154703           1555.774227
# min           9.540300e+04          9253.000000            344.000000
# 25%           1.645305e+05         19335.500000            660.000000
# 50%           4.154810e+05         20567.000000           2177.000000
# 75%           2.262942e+06         37467.000000           3226.500000
# max           3.560764e+06         59484.000000           6845.000000
#
#        patients_hospitalises  total_patients_gueris  \
# count              311.00000             311.000000
# mean             17225.52090          117197.948553
# std               9831.16359           58469.674987
# min               4530.00000           27186.000000
# 25%               6758.00000           76136.500000
# ...

# %%
newd.isnull().sum()
# Out:
# date                                0
# total_cas_confirmes                 0
# total_deces_hopital                 0
# patients_reanimation                0
# patients_hospitalises               0
# total_patients_gueris               0
# nouveaux_patients_hospitalises      0
# nouveaux_patients_reanimation       0
# total_cases                         0
# total_tests                        30
# nouveaux_tests                     30
# positive_ration                    36
# tests_par_cas                      36
# total_vaccinations                256
# personne_vaccinees                256
# nouveaux_vac                      257
# dtype: int64

# %%
newd.drop(columns=["total_vaccinations","personne_vaccinees","nouveaux_vac"],inplace=True)

# %%
d=newd.fillna({'total_tests':0,'nouveaux_tests':0,'tests_par_cas':0,'positive_ration':0})

# %%
d.head(10)
# Out:
#         date  total_cas_confirmes  total_deces_hopital  patients_reanimation  \
# 0  4/12/2020                95403                 9253                  6845
# 1  4/13/2020                98076                 9588                  6821
# 2  4/14/2020               103573                10129                  6730
# 3  4/15/2020               106206                10643                  6457
# 4  4/16/2020               108847                11060                  6248
# 5  4/17/2020               109252                11478                  6027
# 6  4/18/2020               111821                11842                  5833
# 7  4/19/2020               112606                12069                  5744
# 8  4/20/2020               114657                12513                  5683
# 9  4/22/2020               119151                13236                  5218
#
#    patients_hospitalises  total_patients_gueris  \
# 0                  31826                  27186
# ...

# %%
d.isnull().sum()
# Out:
# date                              0
# total_cas_confirmes               0
# total_deces_hopital               0
# patients_reanimation              0
# patients_hospitalises             0
# total_patients_gueris             0
# nouveaux_patients_hospitalises    0
# nouveaux_patients_reanimation     0
# total_cases                       0
# total_tests                       0
# nouveaux_tests                    0
# positive_ration                   0
# tests_par_cas                     0
# dtype: int64

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 13 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   date                            311 non-null    object
#  1   total_cas_confirmes             311 non-null    int64
#  2   total_deces_hopital             311 non-null    int64
#  3   patients_reanimation            311 non-null    int64
#  4   patients_hospitalises           311 non-null    int64
#  5   total_patients_gueris           311 non-null    int64
#  6   nouveaux_patients_hospitalises  311 non-null    int64
#  7   nouveaux_patients_reanimation   311 non-null    int64
#  8   total_cases                     311 non-null    int64
#  9   total_tests                     311 non-null    float64
#  10  nouveaux_tests                  311 non-null    float64
#  11  positive_ration                 311 non-null    float64
# ...

# %%
d.columns
# Out:
# Index(['date', 'total_cas_confirmes', 'total_deces_hopital',
#        'patients_reanimation', 'patients_hospitalises',
#        'total_patients_gueris', 'nouveaux_patients_hospitalises',
#        'nouveaux_patients_reanimation', 'total_cases', 'total_tests',
#        'nouveaux_tests', 'positive_ration', 'tests_par_cas'],
#       dtype='object')

# %%
c=d.sort_values('total_cas_confirmes',ascending=True)
px.bar(
    c.head(300),
    x='date',
    y='total_cas_confirmes',
    title='le nombre des cas confirmés ',
    color_discrete_sequence=['blue'],
    height=500,
    width=800



)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
c=d.sort_values('total_cas_confirmes',ascending=True)
px.bar(
    c.head(300),
    x='date',
    y=  'total_deces_hopital',
    title='le nombre de deces  hospitalisé ',
    color_discrete_sequence=['blue'],
    height=500,
    width=800



)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
c=d.sort_values('total_cas_confirmes',ascending=True)
px.bar(
    c.head(300),
    x='date',
    y=  'patients_reanimation',
    title='le nombre de patient dans le reanimation ',
    color_discrete_sequence=['blue'],
    height=500,
    width=800



)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
c=d.sort_values('total_cas_confirmes',ascending=True)
px.bar(
    c.head(300),
    x='date',
    y= 'patients_hospitalises' ,
    title='le nombre de patient  hospitalisé ',
    color_discrete_sequence=['blue'],
    height=500,
    width=800



)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
c=d.sort_values('total_cas_confirmes',ascending=True)
px.bar(
    c.head(300),
    x='date',
    y=  'total_patients_gueris',
    title='le nombre de patient gueris ',
    color_discrete_sequence=['blue'],
    height=500,
    width=800



)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
c=d.sort_values('total_cas_confirmes',ascending=True)
px.bar(
    c.head(300),
    x='date',
    y=  'nouveaux_patients_hospitalises',
    title='les nouveaux patients  hospitalisés ',
    color_discrete_sequence=['blue'],
    height=500,
    width=800



)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
c=d.sort_values('total_cas_confirmes',ascending=True)
px.bar(
    c.head(300),
    x='date',
    y= 'nouveaux_patients_reanimation' ,
    title='les nouveaux patients  dans la reanimation ',
    color_discrete_sequence=['blue'],
    height=500,
    width=800



)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
c=d.sort_values('total_cas_confirmes',ascending=True)
px.bar(
    c.head(300),
    x='date',
    y= 'total_cases' ,
    title='le nombre des totales cas ',
    color_discrete_sequence=['blue'],
    height=500,
    width=800



)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
c=d.sort_values('total_cas_confirmes',ascending=True)
px.bar(
    c.head(300),
    x='date',
    y=  'total_tests',
    title='le nombre des test ',
    color_discrete_sequence=['blue'],
    height=500,
    width=800



)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
c=d.sort_values('total_cas_confirmes',ascending=True)
px.bar(
    c.head(300),
    x='date',
    y= 'nouveaux_tests' ,
    title='le nombre de nouveaux test',
    color_discrete_sequence=['blue'],
    height=500,
    width=800



)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
c=d.sort_values('total_cas_confirmes',ascending=True)
px.bar(
    c.head(300),
    x='date',
    y= 'positive_ration' ,
    title='le nombre de ration positive ',
    color_discrete_sequence=['blue'],
    height=500,
    width=800



)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
c=d.sort_values('total_cas_confirmes',ascending=True)
px.bar(
    c.head(300),
    x='date',
    y= 'tests_par_cas' ,
    title='le nombre des cas positive par tests ',
    color_discrete_sequence=['blue'],
    height=500,
    width=800



)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
c=d.sort_values('total_cas_confirmes',ascending=False)
c.columns
# Out:
# Index(['date', 'total_cas_confirmes', 'total_deces_hopital',
#        'patients_reanimation', 'patients_hospitalises',
#        'total_patients_gueris', 'nouveaux_patients_hospitalises',
#        'nouveaux_patients_reanimation', 'total_cases', 'total_tests',
#        'nouveaux_tests', 'positive_ration', 'tests_par_cas'],
#       dtype='object')

# %%
c.describe().mode
# Out:
# <bound method DataFrame.mode of        total_cas_confirmes  total_deces_hopital  patients_reanimation  \
# count         3.110000e+02           311.000000            311.000000
# mean          1.125829e+06         27751.881029           2184.327974
# std           1.157963e+06         13004.154703           1555.774227
# min           9.540300e+04          9253.000000            344.000000
# 25%           1.645305e+05         19335.500000            660.000000
# 50%           4.154810e+05         20567.000000           2177.000000
# 75%           2.262942e+06         37467.000000           3226.500000
# max           3.560764e+06         59484.000000           6845.000000
#
#        patients_hospitalises  total_patients_gueris  \
# count              311.00000             311.000000
# mean             17225.52090          117197.948553
# std               9831.16359           58469.674987
# min               4530.00000           27186.000000
# ...
